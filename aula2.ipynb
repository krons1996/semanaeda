# %% [markdown]
# # Estilo Músical
# - rock
# - hip hop
# - mpb
# - reggae
# - funk
# - sertanejo
# - gospel
# - eletrônica

# %% [markdown]
# Objetivo: usar IA na sala de aula, gerando músicas nerds com ritmos de diversos estilos musicais

# %%
! pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/Pesquisa_Simulada_SESI.csv')

# %%
df
# Out:
#    Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0   21/08/2024 10:03:25                                  3
# 1   21/08/2024 10:04:39                                  5
# 2   21/08/2024 10:04:52                                  1
# 3   21/08/2024 10:04:53                                  1
# 4   21/08/2024 10:04:55                                  5
# 5   21/08/2024 10:05:26                                  5
# 6   21/08/2024 10:05:41                                  2
# 7   21/08/2024 10:06:14                                  5
# 8   21/08/2024 10:07:16                                  4
# 9   21/08/2024 10:07:26                                  5
# 10  21/08/2024 10:07:31                                  3
# 11  21/08/2024 10:08:37                                  4
# 12  21/08/2024 10:38:46                                  5
#
#     Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# ...

# %%
df.head()
# Out:
#   Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0  21/08/2024 10:03:25                                  3
# 1  21/08/2024 10:04:39                                  5
# 2  21/08/2024 10:04:52                                  1
# 3  21/08/2024 10:04:53                                  1
# 4  21/08/2024 10:04:55                                  5
#
#    Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 0                                     1                                 1
# 1                                     3                                 5
# 2                                     5                                 1
# 3                                     5                                 4
# 4                                     4                                 3
#
#    Avalie os estilos musicais [reggae]  Avalie os estilos musicais [funk]  \
# 0                                    1                                  1
# ...

# %%
df.columns = ['horadata','rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletronica']

# %%
df.drop('horadata',axis='columns', inplace=True)

# %%
df.head()
# Out:
#    rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletronica
# 0     3       1    1       1     1          1       1           3
# 1     5       3    5       2     1          3       1           5
# 2     1       5    1       1     1          1       1           5
# 3     1       5    4       4     4          1       1           5
# 4     5       4    3       4     1          1       2           5

# %%
df.describe()
# Out:
#             rock     hiphop        mpb     reggae       funk  sertanejo  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    3.692308   3.076923   3.153846   2.153846   2.076923   2.000000
# std     1.548366   1.552500   1.519109   1.281025   1.441153   1.290994
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     3.000000   2.000000   2.000000   1.000000   1.000000   1.000000
# 50%     4.000000   3.000000   3.000000   2.000000   1.000000   1.000000
# 75%     5.000000   4.000000   4.000000   3.000000   4.000000   3.000000
# max     5.000000   5.000000   5.000000   4.000000   4.000000   4.000000
#
#           gospel  eletronica
# count  13.000000   13.000000
# mean    1.846154    3.692308
# std     1.344504    1.250641
# min     1.000000    1.000000
# 25%     1.000000    3.000000
# 50%     1.000000    4.000000
# 75%     2.000000    5.000000
# max     5.000000    5.000000

# %%
df.dtypes
# Out:
# rock          int64
# hiphop        int64
# mpb           int64
# reggae        int64
# funk          int64
# sertanejo     int64
# gospel        int64
# eletronica    int64
# dtype: object

# %%
df.plot(kind='hist', bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns

# %%
sns.histplot(df, kde=True, bins=5)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#             rock     hiphop        mpb     reggae       funk  sertanejo  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    3.692308   3.076923   3.153846   2.153846   2.076923   2.000000
# std     1.548366   1.552500   1.519109   1.281025   1.441153   1.290994
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     3.000000   2.000000   2.000000   1.000000   1.000000   1.000000
# 50%     4.000000   3.000000   3.000000   2.000000   1.000000   1.000000
# 75%     5.000000   4.000000   4.000000   3.000000   4.000000   3.000000
# max     5.000000   5.000000   5.000000   4.000000   4.000000   4.000000
#
#           gospel  eletronica
# count  13.000000   13.000000
# mean    1.846154    3.692308
# std     1.344504    1.250641
# min     1.000000    1.000000
# 25%     1.000000    3.000000
# 50%     1.000000    4.000000
# 75%     2.000000    5.000000
# max     5.000000    5.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df, bins=5)
# Out:
# (array([[2., 1., 2., 2., 6.],
#         [3., 2., 2., 3., 3.],
#         [3., 1., 3., 3., 3.],
#         [6., 2., 2., 3., 0.],
#         [8., 0., 1., 4., 0.],
#         [7., 2., 1., 3., 0.],
#         [8., 2., 1., 1., 1.],
#         [1., 1., 3., 4., 4.]]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <a list of 8 BarContainer objects>)

# %%
# cria o gráfico
plt.hist(df, bins=5)

# titulo no gráfico
plt.title("Pesquisa Simulado SESI")
# Out:
# Text(0.5, 1.0, 'Pesquisa Simulado SESI')
